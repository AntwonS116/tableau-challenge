# %%
import pandas as pd

# %%
file = r"Resources\202108-citibike-tripdata.csv"
file1 = r"Resources\202109-citibike-tripdata.csv"
file2 = r"Resources\202110-citibike-tripdata.csv"

# %%
df = pd.concat([pd.read_csv(file), pd.read_csv(file1), pd.read_csv(file2)])
# Out:
# C:\Users\Antwon\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Antwon\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#                   ride_id rideable_type           started_at  \
# 0        FB6B89D05B67EBED  classic_bike  2021-08-24 15:59:57
# 1        E13DA3E30CEF8DFC  classic_bike  2021-08-18 13:12:01
# 2        56617490AB8AE69C  classic_bike  2021-08-17 14:31:23
# 3        CA908B271C7D6663  classic_bike  2021-08-11 10:00:12
# 4        3E170CE1F4FE179D  classic_bike  2021-08-12 19:28:38
# ...                   ...           ...                  ...
# 3069234  2105A371F0916AF6  classic_bike  2021-10-28 19:00:26
# 3069235  3EE01D46D6630901  classic_bike  2021-10-06 13:34:04
# 3069236  5CA072FFC3C97825  classic_bike  2021-10-27 05:48:47
# 3069237  7CEB5F9904D96DFB  classic_bike  2021-10-12 21:10:01
# 3069238  5F3820B36473D307  classic_bike  2021-10-21 14:42:16
#
#                     ended_at      start_station_name start_station_id  \
# 0        2021-08-24 16:42:07      Broadway & E 21 St           6098.1
# 1        2021-08-18 13:21:26         E 13 St & 2 Ave          5820.08
# ...

# %%
df.dropna(inplace=True)

# %%
df.count()
# Out:
# ride_id               9381427
# rideable_type         9381427
# started_at            9381427
# ended_at              9381427
# start_station_name    9381427
# start_station_id      9381427
# end_station_name      9381427
# end_station_id        9381427
# start_lat             9381427
# start_lng             9381427
# end_lat               9381427
# end_lng               9381427
# member_casual         9381427
# dtype: int64

# %%
df.tail()
# Out:
#                   ride_id rideable_type           started_at  \
# 3069234  2105A371F0916AF6  classic_bike  2021-10-28 19:00:26
# 3069235  3EE01D46D6630901  classic_bike  2021-10-06 13:34:04
# 3069236  5CA072FFC3C97825  classic_bike  2021-10-27 05:48:47
# 3069237  7CEB5F9904D96DFB  classic_bike  2021-10-12 21:10:01
# 3069238  5F3820B36473D307  classic_bike  2021-10-21 14:42:16
#
#                     ended_at      start_station_name start_station_id  \
# 3069234  2021-10-28 19:03:54       6 Ave & Broome St          5610.09
# 3069235  2021-10-06 13:35:28       6 Ave & Broome St          5610.09
# 3069236  2021-10-27 06:02:20  Carlton Ave & Park Ave          4732.04
# 3069237  2021-10-12 21:20:47       6 Ave & Broome St          5610.09
# 3069238  2021-10-21 14:44:15       6 Ave & Broome St          5610.09
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 3069234     Grand St & Greene St        5500.02  40.724310 -74.004730
# ...

# %%
df.to_csv("Resources/CitiBike_data.csv", index=False)
